# %%
# !pip3 uninstall --yes torch torchaudio torchvision torchtext torchdata
# Out:
# Found existing installation: torch 2.5.1+cu121
# Uninstalling torch-2.5.1+cu121:
#   Successfully uninstalled torch-2.5.1+cu121
# Found existing installation: torchaudio 2.5.1+cu121
# Uninstalling torchaudio-2.5.1+cu121:
#   Successfully uninstalled torchaudio-2.5.1+cu121
# Found existing installation: torchvision 0.20.1+cu121
# Uninstalling torchvision-0.20.1+cu121:
#   Successfully uninstalled torchvision-0.20.1+cu121
# WARNING: Skipping torchtext as it is not installed.
# WARNING: Skipping torchdata as it is not installed.

# %%
# !pip install torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 --extra-index-url https://download.pytorch.org/whl/cu116
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# Collecting torch==1.13.1+cu116
#   Downloading https://download.pytorch.org/whl/cu116/torch-1.13.1%2Bcu116-cp310-cp310-linux_x86_64.whl (1977.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 GB ? eta 0:00:00
# Collecting torchvision==0.14.1+cu116
#   Downloading https://download.pytorch.org/whl/cu116/torchvision-0.14.1%2Bcu116-cp310-cp310-linux_x86_64.whl (24.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 58.9 MB/s eta 0:00:00
# Collecting torchaudio==0.13.1
#   Downloading https://download.pytorch.org/whl/cu116/torchaudio-0.13.1%2Bcu116-cp310-cp310-linux_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 86.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1+cu116) (4.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.1+cu116) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.1+cu116) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.1+cu116) (11.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1+cu116) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1+cu116) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1+cu116) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1+cu116) (2024.8.30)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-1.13.1+cu116 torchaudio-0.13.1+cu116 torchvision-0.14.1+cu116

# %%
# !pip install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3
# Out:
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.6)
# Collecting pyspng
#   Downloading pyspng-0.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting ninja
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (5.3 kB)
# Collecting imageio-ffmpeg==0.4.3
#   Downloading imageio_ffmpeg-0.4.3-py3-none-manylinux2010_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyspng) (1.26.4)
# Downloading imageio_ffmpeg-0.4.3-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 10.8 MB/s eta 0:00:00
# Downloading pyspng-0.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (192 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.5/192.5 kB 13.8 MB/s eta 0:00:00
# Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 11.9 MB/s eta 0:00:00
# Installing collected packages: ninja, pyspng, imageio-ffmpeg
#   Attempting uninstall: imageio-ffmpeg
#     Found existing installation: imageio-ffmpeg 0.5.1
#     Uninstalling imageio-ffmpeg-0.5.1:
#       Successfully uninstalled imageio-ffmpeg-0.5.1
# Successfully installed imageio-ffmpeg-0.4.3 ninja-1.11.1.1 pyspng-0.1.2

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 131 (delta 0), reused 1 (delta 0), pack-reused 128 (from 1)
# Receiving objects: 100% (131/131), 1.13 MiB | 21.44 MiB/s, done.
# Resolving deltas: 100% (57/57), done.

# %%
# !wget https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl
# Out:
# --2024-11-22 04:36:56--  https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl
# Resolving nvlabs-fi-cdn.nvidia.com (nvlabs-fi-cdn.nvidia.com)... 3.165.82.69, 3.165.82.67, 3.165.82.11, ...
# Connecting to nvlabs-fi-cdn.nvidia.com (nvlabs-fi-cdn.nvidia.com)|3.165.82.69|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 381624121 (364M) [binary/octet-stream]
# Saving to: ‘ffhq.pkl’
#
# ffhq.pkl            100%[===================>] 363.94M  55.5MB/s    in 6.6s
#
# 2024-11-22 04:37:03 (55.5 MB/s) - ‘ffhq.pkl’ saved [381624121/381624121]

# %%
import sys
sys.path.append('/content/stylegan2-ada-pytorch')

# %%
import pickle
import torch

# %%
with open('ffhq.pkl', 'rb') as f:
    G = pickle.load(f)['G_ema'].cuda()  # torch.nn.Module
z = torch.randn([1, G.z_dim]).cuda()    # latent codes
c = None                                # class labels (not used in this example)
img = G(z, c)                           # NCHW, float32, dynamic range [-1, +1]
# Out:
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.

# %%
import matplotlib.pyplot as plt

img_cpu = img.detach().cpu()

img_display = img_cpu.squeeze(0).permute(1, 2, 0)

img_display = (img_display + 1) / 2

plt.figure(figsize=(10, 10))
plt.imshow(img_display)
plt.axis('off')
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

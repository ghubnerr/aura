# %%
# %pip install opencv-python numpy kagglehub
# Out:
# usage: conda [-h] [-V] command ...
#
# conda is a tool for managing and deploying applications, environments and packages.
#
# Options:
#
# positional arguments:
#   command
#     clean        Remove unused packages and caches.
#     compare      Compare packages between conda environments.
#     config       Modify configuration values in .condarc. This is modeled
#                  after the git config command. Writes to the user .condarc
#                  file (/aul/homes/dvahi001/.condarc) by default.
#     create       Create a new conda environment from a list of specified
#                  packages.
#     help         Displays a list of available conda commands and their help
#                  strings.
#     info         Display information about current conda install.
#     init         Initialize conda for shell interaction. [Experimental]
#     install      Installs a list of packages into a specified conda
#                  environment.
#     list         List linked packages in a conda environment.
#     package      Low-level conda package utility. (EXPERIMENTAL)
#     remove       Remove a list of packages from a specified conda environment.
#     uninstall    Alias for conda remove.
#     run          Run an executable in a conda environment. [Experimental]
#     search       Search for packages and display associated information. The
#                  input is a MatchSpec, a query language for conda packages.
#                  See examples below.
#     update       Updates conda packages to the latest compatible version.
#     upgrade      Alias for conda update.
#
# optional arguments:
#   -h, --help     Show this help message and exit.
#   -V, --version  Show the conda version number and exit.
#
# conda commands available from other packages:
#   env
# usage: conda [-h] [-V] command ...
#
# conda is a tool for managing and deploying applications, environments and packages.
#
# Options:
#
# positional arguments:
#   command
#     clean        Remove unused packages and caches.
#     compare      Compare packages between conda environments.
#     config       Modify configuration values in .condarc. This is modeled
#                  after the git config command. Writes to the user .condarc
#                  file (/aul/homes/dvahi001/.condarc) by default.
#     create       Create a new conda environment from a list of specified
#                  packages.
#     help         Displays a list of available conda commands and their help
#                  strings.
#     info         Display information about current conda install.
#     init         Initialize conda for shell interaction. [Experimental]
#     install      Installs a list of packages into a specified conda
#                  environment.
#     list         List linked packages in a conda environment.
#     package      Low-level conda package utility. (EXPERIMENTAL)
#     remove       Remove a list of packages from a specified conda environment.
#     uninstall    Alias for conda remove.
#     run          Run an executable in a conda environment. [Experimental]
#     search       Search for packages and display associated information. The
#                  input is a MatchSpec, a query language for conda packages.
#                  See examples below.
#     update       Updates conda packages to the latest compatible version.
#     upgrade      Alias for conda update.
#
# optional arguments:
#   -h, --help     Show this help message and exit.
#   -V, --version  Show the conda version number and exit.
#
# conda commands available from other packages:
#   env
# Requirement already satisfied: opencv-python in /a/buffalo.cs.fiu.edu./disk/jccl-002/homes/dvahi001/miniconda3/envs/aura/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: numpy in /a/buffalo.cs.fiu.edu./disk/jccl-002/homes/dvahi001/miniconda3/envs/aura/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: kagglehub in /a/buffalo.cs.fiu.edu./disk/jccl-002/homes/dvahi001/miniconda3/envs/aura/lib/python3.10/site-packages (0.3.3)
# Requirement already satisfied: packaging in /a/buffalo.cs.fiu.edu./disk/jccl-002/homes/dvahi001/miniconda3/envs/aura/lib/python3.10/site-packages (from kagglehub) (24.1)
# Requirement already satisfied: requests in /a/buffalo.cs.fiu.edu./disk/jccl-002/homes/dvahi001/miniconda3/envs/aura/lib/python3.10/site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /a/buffalo.cs.fiu.edu./disk/jccl-002/homes/dvahi001/miniconda3/envs/aura/lib/python3.10/site-packages (from kagglehub) (4.66.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /a/buffalo.cs.fiu.edu./disk/jccl-002/homes/dvahi001/miniconda3/envs/aura/lib/python3.10/site-packages (from requests->kagglehub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /a/buffalo.cs.fiu.edu./disk/jccl-002/homes/dvahi001/miniconda3/envs/aura/lib/python3.10/site-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /a/buffalo.cs.fiu.edu./disk/jccl-002/homes/dvahi001/miniconda3/envs/aura/lib/python3.10/site-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /a/buffalo.cs.fiu.edu./disk/jccl-002/homes/dvahi001/miniconda3/envs/aura/lib/python3.10/site-packages (from requests->kagglehub) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import numpy as np
from PIL import Image as PILImage
from IPython.display import display


PATH = "./processed_images/"

def resize_image(image, target_size=(224, 224)):
    # If the image is grayscale, convert it to 3 channels (RGB)
    if len(image.shape) == 2:
        image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)

    h, w = image.shape[:2]
    scale = min(target_size[0] / h, target_size[1] / w)
    new_w = int(w * scale)
    new_h = int(h * scale)

    resized_image = cv2.resize(image, (new_w, new_h))
    canvas = np.zeros((target_size[0], target_size[1], 3), dtype=np.uint8)
    top = (target_size[0] - new_h) // 2
    left = (target_size[1] - new_w) // 2
    canvas[top:top + new_h, left:left + new_w] = resized_image

    return canvas



def set_black_background(image, threshold=20):
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, mask = cv2.threshold(gray_image, threshold, 255, cv2.THRESH_BINARY_INV)
    image[mask == 255] = [0, 0, 0]
    return image


def preprocess_image(image, grayscale=True, target_size=(224, 224)):
    image = resize_image(image, target_size)
    image = set_black_background(image)
    if grayscale:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    return image


def random_rotation(image):
    angle = np.random.uniform(-30, 30)
    h, w = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    return cv2.warpAffine(image, M, (w, h))

def random_flip(image):
    if np.random.rand() > 0.5:
        return cv2.flip(image, 1)  
    return image

def random_brightness(image):
    factor = np.random.uniform(0.5, 1.5)
    return cv2.convertScaleAbs(image, alpha=factor, beta=0)


def random_zoom(image):
    h, w = image.shape[:2]
    zoom = np.random.uniform(0.3, 2.0)  
    new_h, new_w = int(h * zoom), int(w * zoom)
    image = cv2.resize(image, (new_w, new_h))
    if new_h < h or new_w < w:
        top = (h - new_h) // 2
        left = (w - new_w) // 2
        cropped = image[top:top + new_h, left:left + new_w]
    else:
        cropped = image[:h, :w]
    return resize_image(cropped)


def save_processed_images(image_files, batch_size=50, output_dir="./augmented_photos"):
    os.makedirs(output_dir, exist_ok=True)    
    for i, image_file in enumerate(image_files):
        image_path = os.path.join(PATH, image_file)
        print(f"Processing image: {image_path}")

        # Load the image
        image = cv2.imread(image_path)

        # Check if the image is loaded correctly
        if image is None:
            print(f"Error: Failed to load image {image_path}")
            continue  # Skip this image and move to the next one

        processed_image = preprocess_image(image)

        # Apply augmentations and save each one
        try:
            rotation_image = random_rotation(processed_image)
            rotation_path = os.path.join(output_dir, f"rotated_{i + 1}.jpg")
            PILImage.fromarray(cv2.cvtColor(rotation_image, cv2.COLOR_BGR2RGB)).save(rotation_path)

            flip_image = random_flip(processed_image)
            flip_path = os.path.join(output_dir, f"flipped_{i + 1}.jpg")
            PILImage.fromarray(cv2.cvtColor(flip_image, cv2.COLOR_BGR2RGB)).save(flip_path)

            brightness_image = random_brightness(processed_image)
            brightness_path = os.path.join(output_dir, f"brightness_{i + 1}.jpg")
            PILImage.fromarray(cv2.cvtColor(brightness_image, cv2.COLOR_BGR2RGB)).save(brightness_path)

            zoom_image = random_zoom(processed_image)
            zoom_path = os.path.join(output_dir, f"zoomed_{i + 1}.jpg")
            PILImage.fromarray(cv2.cvtColor(zoom_image, cv2.COLOR_BGR2RGB)).save(zoom_path)

            print(f"Processed images for {image_file} saved to {output_dir}")
        except Exception as e:
            print(f"Error processing image {image_file}: {e}")

# %%
image_files = [f for f in os.listdir(PATH) if f.endswith(('.png', '.jpg', '.jpeg'))]
save_processed_images(image_files)
# Out:
# Processing image: ./processed_images/fear_449.jpg
# Processed images for fear_449.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_498.jpg
# Processed images for fear_498.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_30.jpg
# Processed images for happy_30.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_511.jpg
# Processed images for fear_511.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_110.jpg
# Processed images for happy_110.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_435.jpg
# Processed images for fear_435.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry_360.jpg
# Processed images for angry_360.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry
jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_25.jpg
# Processed images for happy_25.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_431.jpg
# Processed images for fear_431.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry_364.jpg
# Processed images for angry_364.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_48.jpg
# Processed images for happy_48.jpg saved to ./augmented_photos
# Processing image: ./processed_images/sad_212.jpg
# Processed images for sad_212.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_99.jpg
# Processed images for happy_99.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry_412.jpg
# Processed images for angry_412.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_168.jpg
# Processed images for happy_168.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry_318.jpg
# Processed images for angry_318.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_34.jpg
# Processed images for happy_34.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_114.jpg
# Processed images for happy_114.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_515.jpg
# Processed images for fear_515.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_33.jpg
# Processed images for happy_33.jpg saved to ./augmented_photos
# Processing image: ./processed_images/sad_269.jpg
# Processed images for sad_269.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_113.jpg
# Processed images for happy_113.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_512.jpg
# Processed images for fear_512.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_436.jpg
# Processed images for fear_436.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry_363.jpg
# Processed images for angry_363.jpg saved to ./augmented_photos
# Processing image: ./processed_images/sad_215.jpg
# Processed images for sad_215.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry_415.jpg
# Processed images for angry_415.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_444.jpg
# Processed images for fear_444.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_495.jpg
# Processed images for fear_495.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry_311.jpg
# Processed images for angry_311.jpg saved to ./augmented_photos
# Processing image: ./processed_images/sad_267.jpg
# Processed images for sad_267.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_438.jpg
# Processed images for fear_438.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_41.jpg
# Processed images for happy_41.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_90.jpg
# Processed images for happy_90.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_161.jpg
# Processed images for happy_161.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_46.jpg
# Processed images for happy_46.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_97.jpg
# Processed images for happy_97.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_166.jpg
# Processed images for happy_166.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_443.jpg
# Processed images for fear_443.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_492.jpg
# Processed images for fear_492.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry_316.jpg
# Processed images for angry_316.jpg saved to ./augmented_photos
# Processing image: ./processed_images/sad_260.jpg
# Processed images for sad_260.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_153.jpg
# Processed images for happy_153.jpg saved to ./augmented_photos
# Processing image: ./processed_images/sad_229.jpg
# Processed images for sad_229.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_73.jpg
# Processed images for happy_73.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_182.jpg
# Processed images for happy_182.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_476.jpg
# Processed images for fear_476.jpg saved to ./augmented_photos
# Processing image: ./processed_images/sad_193.jpg
# Processed images for sad_193.jpg saved to ./augmented_photos
# Processing image: ./processed_images/sad_255.jpg
# Processed images for sad_255.jpg saved to ./augmented_photos
# Processing image: ./processed_images/sad_284.jpg
# Processed images for sad_284.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry_323.jpg
# Processed images for angry_323.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_471.jpg
# Processed images for fear_471.jpg saved to ./augmented_photos
# Processing image: ./processed_images/sad_194.jpg
# Processed images for sad_194.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_128.jpg
# Processed images for happy_128.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_529.jpg
# Error processing image fear_529.jpg: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Processing image: ./processed_images/sad_252.jpg
# Processed images for sad_252.jpg saved to ./augmented_photos
# Processing image: ./processed_images/sad_283.jpg
# Processed images for sad_283.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry_324.jpg
# Error processing image angry_324.jpg: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Processing image: ./processed_images/happy_154.jpg
# Processed images for happy_154.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry_389.jpg
# Processed images for angry_389.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_74.jpg
# Processed images for happy_74.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry_358.jpg
# Processed images for angry_358.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_185.jpg
# Processed images for happy_185.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_527.jpg
# Processed images for fear_527.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_126.jpg
# Processed images for happy_126.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry_420.jpg
# Processed images for angry_420.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry_387.jpg
# Processed images for angry_387.jpg saved to ./augmented_photos
# Processing image: ./processed_images/sad_220.jpg
# Processed images for sad_220.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry_356.jpg
# Processed images for angry_356.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry_380.jpg
# Processed images for angry_380.jpg saved to ./augmented_photos
# Processing image: ./processed_images/sad_227.jpg
# Processed images for sad_227.jpg saved to ./augmented_photos
# Processing image: ./processed_images/angry_351.jpg
# Processed images for angry_351.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_478.jpg
# Processed images for fear_478.jpg saved to ./augmented_photos
# Processing image: ./processed_images/fear_520.jpg
# Processed images for fear_520.jpg saved to ./augmented_photos
# Processing image: ./processed_images/happy_121.jpg
# Processed images for happy_121.jpg saved to ./augmented_photos
